# %%
import pandas as pd
csv_path = "raw_data/schools_complete.csv"
school_df = pd.read_csv(csv_path)
school_df.head()
import numpy as np

# %%
new_school_df = school_df.rename(columns={"name":"school"})
new_school_df.head(20)
# Out:
#     School ID                 school      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
count = school_df["name"].value_counts()
count
# Out:
# Hernandez High School    1
# Shelton High School      1
# Cabrera High School      1
# Wright High School       1
# Wilson High School       1
# Griffin High School      1
# Figueroa High School     1
# Pena High School         1
# Bailey High School       1
# Holden High School       1
# Huang High School        1
# Rodriguez High School    1
# Ford High School         1
# Thomas High School       1
# Johnson High School      1
# Name: name, dtype: int64

# %%
school_df.describe()
# Out:
#        School ID         size        budget
# count  15.000000    15.000000  1.500000e+01
# mean    7.000000  2611.333333  1.643295e+06
# std     4.472136  1420.915282  9.347763e+05
# min     0.000000   427.000000  2.480870e+05
# 25%     3.500000  1698.000000  1.046265e+06
# 50%     7.000000  2283.000000  1.319574e+06
# 75%    10.500000  3474.000000  2.228999e+06
# max    14.000000  4976.000000  3.124928e+06

# %%
csv_path = "raw_data/students_complete.csv"
student_df = pd.read_csv(csv_path)
student_df.describe()
# Out:
#          Student ID  reading_score    math_score
# count  39170.000000    39170.00000  39170.000000
# mean   19584.500000       81.87784     78.985371
# std    11307.549359       10.23958     12.309968
# min        0.000000       63.00000     55.000000
# 25%     9792.250000       73.00000     69.000000
# 50%    19584.500000       82.00000     79.000000
# 75%    29376.750000       91.00000     89.000000
# max    39169.000000       99.00000     99.000000

# %%
student_df.head()
# Out:
#    Student ID               name gender grade             school  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
combo_df = pd.merge(new_school_df, student_df, on="school")
combo_df.head()
# Out:
#    School ID             school      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
# 2          0  Huang High School  District  2917  1910635           2
# 3          0  Huang High School  District  2917  1910635           3
# 4          0  Huang High School  District  2917  1910635           4
#
#                 name gender grade  reading_score  math_score
# 0       Paul Bradley      M   9th             66          79
# 1       Victor Smith      M  12th             94          61
# 2    Kevin Rodriguez      M  12th             90          60
# 3  Dr. Richard Scott      M  12th             67          58
# 4         Bonnie Ray      F   9th             97          84

# %%
combo_df.columns
# Out:
# Index(['School ID', 'school', 'type', 'size', 'budget', 'Student ID', 'name',
#        'gender', 'grade', 'reading_score', 'math_score'],
#       dtype='object')

# %%
combo_df.describe()
# Out:
#           School ID          size        budget    Student ID  reading_score  \
# count  39170.000000  39170.000000  3.917000e+04  39170.000000    39170.00000
# mean       6.978172   3332.957110  2.117241e+06  19584.500000       81.87784
# std        4.444329   1323.914069  8.749987e+05  11307.549359       10.23958
# min        0.000000    427.000000  2.480870e+05      0.000000       63.00000
# 25%        3.000000   1858.000000  1.081356e+06   9792.250000       73.00000
# 50%        7.000000   2949.000000  1.910635e+06  19584.500000       82.00000
# 75%       11.000000   4635.000000  3.022020e+06  29376.750000       91.00000
# max       14.000000   4976.000000  3.124928e+06  39169.000000       99.00000
#
#          math_score
# count  39170.000000
# mean      78.985371
# std       12.309968
# min       55.000000
# 25%       69.000000
# 50%       79.000000
# 75%       89.000000
# max       99.000000

# %%
#**District Summary**

#* Create a high level snapshot (in table form) of the district's key metrics, including:
#* Total Schools
#* Total Students
#* Total Budget
#* Average Math Score
#* Average Reading Score
#* % Passing Math
#* % Passing Reading
  #* Overall Passing Rate (Average of the above two)

# %%
#*********************************************************

score_grade_df = combo_df.groupby(['school','grade'])
score_grade_df.head()
# Out:
#        School ID                school      type  size   budget  Student ID  \
# 0              0     Huang High School  District  2917  1910635           0
# 1              0     Huang High School  District  2917  1910635           1
# 2              0     Huang High School  District  2917  1910635           2
# 3              0     Huang High School  District  2917  1910635           3
# 4              0     Huang High School  District  2917  1910635           4
# 5              0     Huang High School  District  2917  1910635           5
# 6              0     Huang High School  District  2917  1910635           6
# 7              0     Huang High School  District  2917  1910635           7
# 8              0     Huang High School  District  2917  1910635           8
# 9              0     Huang High School  District  2917  1910635           9
# 10             0     Huang High School  District  2917  1910635          10
# ...

# %%
Total_School = combo_df.groupby('school')['School ID'].nunique()
Total_School
# Out:
# school
# Bailey High School       1
# Cabrera High School      1
# Figueroa High School     1
# Ford High School         1
# Griffin High School      1
# Hernandez High School    1
# Holden High School       1
# Huang High School        1
# Johnson High School      1
# Pena High School         1
# Rodriguez High School    1
# Shelton High School      1
# Thomas High School       1
# Wilson High School       1
# Wright High School       1
# Name: School ID, dtype: int64

# %%
Total_School.count()
# Out:
# 15

# %%
Total_Student = combo_df["Student ID"].nunique()
Total_Student
# Out:
# 39170

# %%
#Total Budget = combo_df["budget"].sum()

Total_Budget = new_school_df["budget"].sum()
Total_Budget
# Out:
# 24649428

# %%
#Average Math Score = combo_df["math_score"].mean()

Average_Math = round(combo_df["math_score"].mean(),2)
Average_Math
# Out:
# 78.99

# %%
#Average Reading  Score = combo_df["reading_score"].mean()

Average_Reading = round(combo_df["reading_score"].mean(),2)
Average_Reading
# Out:
# 81.88

# %%
#% Passing Math
combo_pass_df = combo_df[combo_df["math_score"] > 75]
bins = [0,75,100]
# Create labels for these bins
group_labels = ["Fail","Pass"]

# %%
combo_pass_df["Math Pass Group"] = pd.cut(combo_pass_df["math_score"], bins,labels=group_labels)
combo_pass_df.head()
# Out:
# C:\Users\Satyanand.Madakshira\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    School ID             school      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 4          0  Huang High School  District  2917  1910635           4
# 5          0  Huang High School  District  2917  1910635           5
# 6          0  Huang High School  District  2917  1910635           6
# 8          0  Huang High School  District  2917  1910635           8
#
#             name gender grade  reading_score  math_score Reading Pass Group  \
# ...

# %%
combo_pass_df["Math Pass Group"].count()
# Out:
# 23456

# %%
Total_Pass_Math = combo_pass_df["Math Pass Group"].count()
Total_Pass_Math
# Out:
# 23456

# %%
combo_pass_df = combo_df[combo_df["reading_score"] > 75]
bins = [0,75,100]
# Create labels for these bins
group_labels = ["Fail","Pass"]

# %%
combo_pass_df["Reading Pass Group"] = pd.cut(combo_pass_df["reading_score"], bins,labels=group_labels)
combo_pass_df.head()
# Out:
# C:\Users\Satyanand.Madakshira\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    School ID             school      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 4          0  Huang High School  District  2917  1910635           4
# 5          0  Huang High School  District  2917  1910635           5
# 6          0  Huang High School  District  2917  1910635           6
# 8          0  Huang High School  District  2917  1910635           8
#
#             name gender grade  reading_score  math_score Reading Pass Group
# ...

# %%
combo_pass_df["Reading Pass Group"].count()
# Out:
# 23456

# %%
Total_Pass_Read = combo_pass_df["Reading Pass Group"].count()
Total_Pass_Read
# Out:
# 23456

# %%
modified_District_summary_df = District_summary_df.loc[:,["Total School",
                                                          "Total Students",
                                                          "Total Budget"]]
modified_District_summary_df
# Out:
#    Total School  Total Students  Total Budget
# 0            15           39170      24649428

# %%
#Percentage Calcualtions per school
scores = pd.DataFrame({
        "Math_Pass":[23456],
    "Reading_Pass":[26940],
    "Total Students":[39170],
    "Average Math Score": [78.99],
    "Average Reading Score": [81.88],
    " % Passing Math" :[(23456/39170)*100],
    " % Passing Reading" :[(26940/39170)*100],
    " % Overall Passing Rate" :[(((23456+26940)/2)/39170)*100],
    "Total Schools":[15],
    "Total Budget":[24649428]
})
final_score_df = scores.loc[:,["Total Schools", "Total Students", "Total Budget", "Average Math Score", "Average Reading Score", " % Passing Math", " % Passing Reading"," % Overall Passing Rate"]]
final_score_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428               78.99
#
#    Average Reading Score   % Passing Math   % Passing Reading  \
# 0                  81.88        59.882563           68.777125
#
#     % Overall Passing Rate
# 0                64.329844

# %%
#**School Summary**

#* Create an overview table that summarizes key metrics about each school, including:
 # * School Name
  #* School Type
  #* Total Students
  #* Total School Budget
  #* Per School Budget
  #* Average Math Score
  #* Average Reading Score
  #* % Passing Math
  #* % Passing Reading
  #* Overall Passing Rate (Average of the above two)

# %%
combo_df.columns
# Out:
# Index(['School ID', 'school', 'type', 'size', 'budget', 'Student ID', 'name',
#        'gender', 'grade', 'reading_score', 'math_score'],
#       dtype='object')

# %%
summary_combo_df = combo_df.groupby("school")
summary_combo_df.mean()
# Out:
#                        School ID    size     budget  Student ID  \
# school
# Bailey High School           7.0  4976.0  3124928.0     20358.5
# Cabrera High School          6.0  1858.0  1081356.0     16941.5
# Figueroa High School         1.0  2949.0  1884411.0      4391.0
# Ford High School            13.0  2739.0  1763916.0     36165.0
# Griffin High School          4.0  1468.0   917500.0     12995.5
# Hernandez High School        3.0  4635.0  3022020.0      9944.0
# Holden High School           8.0   427.0   248087.0     23060.0
# Huang High School            0.0  2917.0  1910635.0      1458.0
# Johnson High School         12.0  4761.0  3094650.0     32415.0
# Pena High School             9.0   962.0   585858.0     23754.5
# Rodriguez High School       11.0  3999.0  2547363.0     28035.0
# Shelton High School          2.0  1761.0  1056600.0      6746.0
# Thomas High School          14.0  1635.0  1043130.0     38352.0
# ...

# %%
new_school_df.head(15)
# Out:
#     School ID                 school      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
per_student_budget = new_school_df['budget']/new_school_df['size']
per_student_budget.head(15)
# Out:
# 0     655.0
# 1     639.0
# 2     600.0
# 3     652.0
# 4     625.0
# 5     578.0
# 6     582.0
# 7     628.0
# 8     581.0
# 9     609.0
# 10    583.0
# 11    637.0
# 12    650.0
# 13    644.0
# 14    638.0
# dtype: float64

# %%
school_scores_df = pd.DataFrame({
            "School Name": ["Bailey High School", "Cabrera High School", "Figueroa High School", "Ford High School", "Griffin High School", "Hernandez High School", "Holden High School", "Huang High School", "Johnson High School", "Pena High School", "Rodriguez High School", "Shelton High School", "Thomas High School","Wilson High School", "Wright High School"],
            "Count Math_Pass":[2779, 1413, 1594, 1551, 1147, 2601, 337, 1574, 2611, 747, 2200, 1386, 1279, 1772, 1429],
            "Count Reading_Pass":[3439, 1489, 2027, 1827, 1162, 3109, 336, 2002, 3233, 781, 2678, 1397, 1292, 1849, 1468],
            "Count Overall_Pass" :[1926, 1132, 1083, 1050, 900, 1731, 263, 1081, 1760, 615, 1452, 1098, 1008, 1436, 1160],
            "% Passing Math" : [0.56, 0.76, 0.54, 0.57, 0.78, 0.56, 0.79, 0.54, 0.55, 0.78, 0.55, 0.79, 0.78, 0.78, 0.79],
            "% Passing Reading": [0.69, 0.80, 0.69, 0.67, 0.79, 0.67, 0.79, 0.69, 0.68, 0.81, 0.67, 0.79, 0.79, 0.81, 0.82],
            "% Overall Passing Rate" : [0.39, 0.61, 0.37,0.38, 0.61, 0.37, 0.62, 0.37, 0.37, 0.64, 0.36, 0.62, 0.62, 0.63, 0.64],
            "School Type" : ["District", "Charter", "District", "District", "Charter", "District", "Charter", "District", "District", "Charter", "District", "Charter", "Charter", "Charter", "Charter"],
            "School Size" : [4976, 1858, 2949, 2739, 1468, 4635, 427, 2917, 4761, 962, 3999, 1761, 1635, 2283, 1800],
            "Budget" : [3124928, 1081356, 1884411, 1763916, 917500, 3022020, 248087, 1910635, 3094650, 585858, 2547363, 1056600, 1043130, 1319574, 1049400],
            "Budget Per Student" : [628, 582, 639, 644, 625, 652, 581, 655, 650, 609, 637, 600, 638, 578, 583],
            "Average Math Score" : [77.05, 83.06, 76.71, 77.10, 83.35, 77.29, 83.80, 76.63, 77.07, 83.84, 76.84, 83.36, 83.42, 83.27, 83.68],
            "Average Reading Score" : [81.03, 83.98, 81.16, 80.75, 83.82, 80.93, 83.81, 81.18, 80.97, 84.04, 80.74, 83.73, 83.85, 83.99, 83.96]
        })
school_scores_df.head(15)
# Out:
#     % Overall Passing Rate  % Passing Math  % Passing Reading  \
# 0                     0.39            0.56               0.69
# 1                     0.61            0.76               0.80
# 2                     0.37            0.54               0.69
# 3                     0.38            0.57               0.67
# 4                     0.61            0.78               0.79
# 5                     0.37            0.56               0.67
# 6                     0.62            0.79               0.79
# 7                     0.37            0.54               0.69
# 8                     0.37            0.55               0.68
# 9                     0.64            0.78               0.81
# 10                    0.36            0.55               0.67
# 11                    0.62            0.79               0.79
# 12                    0.62            0.78               0.79
# 13                    0.63            0.78               0.81
# ...

# %%
final_school_score_df = school_scores_df.loc[:,["School Name", "School Type", "School Size", "Budget", "Budget Per Student", "Average Math Score", "Average Reading Score","% Passing Math", "% Passing Reading", "% Overall Passing Rate"]]
final_school_score_df.head(15)
# Out:
#               School Name School Type  School Size   Budget  \
# 0      Bailey High School    District         4976  3124928
# 1     Cabrera High School     Charter         1858  1081356
# 2    Figueroa High School    District         2949  1884411
# 3        Ford High School    District         2739  1763916
# 4     Griffin High School     Charter         1468   917500
# 5   Hernandez High School    District         4635  3022020
# 6      Holden High School     Charter          427   248087
# 7       Huang High School    District         2917  1910635
# 8     Johnson High School    District         4761  3094650
# 9        Pena High School     Charter          962   585858
# 10  Rodriguez High School    District         3999  2547363
# 11    Shelton High School     Charter         1761  1056600
# 12     Thomas High School     Charter         1635  1043130
# 13     Wilson High School     Charter         2283  1319574
# 14     Wright High School     Charter         1800  1049400
#
# ...

# %%
Top_Schools_df = final_school_score_df.sort_values("% Overall Passing Rate", ascending=False)
Top_Schools_df.head()
# Out:
#             School Name School Type  School Size   Budget  Budget Per Student  \
# 9      Pena High School     Charter          962   585858                 609
# 14   Wright High School     Charter         1800  1049400                 583
# 13   Wilson High School     Charter         2283  1319574                 578
# 6    Holden High School     Charter          427   248087                 581
# 11  Shelton High School     Charter         1761  1056600                 600
#
#     Average Math Score  Average Reading Score  % Passing Math  \
# 9                83.84                  84.04            0.78
# 14               83.68                  83.96            0.79
# 13               83.27                  83.99            0.78
# 6                83.80                  83.81            0.79
# 11               83.36                  83.73            0.79
#
#     % Passing Reading  % Overall Passing Rate
# 9                0.81                    0.64
# ...

# %%
Low_Schools_df = final_school_score_df.sort_values("% Overall Passing Rate")
Low_Schools_df.head()
# Out:
#               School Name School Type  School Size   Budget  \
# 10  Rodriguez High School    District         3999  2547363
# 2    Figueroa High School    District         2949  1884411
# 5   Hernandez High School    District         4635  3022020
# 7       Huang High School    District         2917  1910635
# 8     Johnson High School    District         4761  3094650
#
#     Budget Per Student  Average Math Score  Average Reading Score  \
# 10                 637               76.84                  80.74
# 2                  639               76.71                  81.16
# 5                  652               77.29                  80.93
# 7                  655               76.63                  81.18
# 8                  650               77.07                  80.97
#
#     % Passing Math  % Passing Reading  % Overall Passing Rate
# 10            0.55               0.67                    0.36
# 2             0.54               0.69                    0.37
# ...

# %%
student_df.columns
# Out:
# Index(['Student ID', 'name', 'gender', 'grade', 'school', 'reading_score',
#        'math_score'],
#       dtype='object')

# %%
student_df.head()
# Out:
#    Student ID               name gender grade             school  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
summary_math_school_df = pd.DataFrame({
            "School Name": ["Bailey High School", "Cabrera High School", "Figueroa High School", "Ford High School", "Griffin High School", "Hernandez High School", "Holden High School", "Huang High School", "Johnson High School", "Pena High School", "Rodriguez High School", "Shelton High School", "Thomas High School","Wilson High School", "Wright High School"],
            "9th":[77.08, 83.09, 76.40, 77.36, 82.04, 77.44, 83.79, 77.03, 77.19, 83.63, 76.86, 83.42, 83.59, 83.09, 83.26],
            "10th":[77.00, 83.15, 76.54, 77.67, 84.23, 77.34, 83.43, 75.91, 76.69, 83.37, 76.61, 82.92, 83.09, 83.72, 84.01],
            "11th":[77.52, 82.77, 76.88, 76.92, 83.84, 77.14, 85.00, 76.45, 77.49, 84.33, 76.40, 83.38, 83.50, 83.20, 83.84],
            "12th":[76.49, 83.28, 77.15, 76.18, 83.36, 77.19, 82.86, 77.23, 76.86, 84.12, 77.69, 83.78, 83.50, 83.04, 83.64],
            })
final_math_school_df = summary_math_school_df.loc[:,["School Name","9th", "10th", "11th", "12th"]]
final_math_school_df.head(15)
# Out:
#               School Name    9th   10th   11th   12th
# 0      Bailey High School  77.08  77.00  77.52  76.49
# 1     Cabrera High School  83.09  83.15  82.77  83.28
# 2    Figueroa High School  76.40  76.54  76.88  77.15
# 3        Ford High School  77.36  77.67  76.92  76.18
# 4     Griffin High School  82.04  84.23  83.84  83.36
# 5   Hernandez High School  77.44  77.34  77.14  77.19
# 6      Holden High School  83.79  83.43  85.00  82.86
# 7       Huang High School  77.03  75.91  76.45  77.23
# 8     Johnson High School  77.19  76.69  77.49  76.86
# 9        Pena High School  83.63  83.37  84.33  84.12
# 10  Rodriguez High School  76.86  76.61  76.40  77.69
# 11    Shelton High School  83.42  82.92  83.38  83.78
# 12     Thomas High School  83.59  83.09  83.50  83.50
# 13     Wilson High School  83.09  83.72  83.20  83.04
# 14     Wright High School  83.26  84.01  83.84  83.64

# %%
summary_reading_school_df = pd.DataFrame({
        "School Name": ["Bailey High School", "Cabrera High School", "Figueroa High School", "Ford High School", "Griffin High School", "Hernandez High School", "Holden High School", "Huang High School", "Johnson High School", "Pena High School", "Rodriguez High School", "Shelton High School", "Thomas High School","Wilson High School", "Wright High School"],
        "9th":[ 81.30, 83.68, 81.20, 80.63, 83.37, 80.87, 83.68, 81.29, 81.26, 83.81, 80.99, 84.12, 83.73, 83.94, 83.83],
        "10th":[80.91, 84.25, 81.41, 81.26, 83.71, 80.66, 83.32, 81.51, 80.77, 83.61, 80.63, 83.44, 84.25, 84.02, 83.81],
        "11th":[80.95, 83.79, 80.64, 80.40, 84.29, 81.40, 83.82, 81.42, 80.62, 84.34, 80.86, 84.37, 83.59, 83.76, 84.16],
        "12th":[80.91, 84.29, 81.38, 80.66, 84.01, 80.86, 84.70, 80.31, 81.23, 84.59, 80.38, 82.78, 83.83, 84.32, 84.07],
        })
final_reading_school_df = summary_reading_school_df.loc[:,["School Name","9th", "10th", "11th", "12th"]]
final_reading_school_df.head(15)
# Out:
#               School Name    9th   10th   11th   12th
# 0      Bailey High School  81.30  80.91  80.95  80.91
# 1     Cabrera High School  83.68  84.25  83.79  84.29
# 2    Figueroa High School  81.20  81.41  80.64  81.38
# 3        Ford High School  80.63  81.26  80.40  80.66
# 4     Griffin High School  83.37  83.71  84.29  84.01
# 5   Hernandez High School  80.87  80.66  81.40  80.86
# 6      Holden High School  83.68  83.32  83.82  84.70
# 7       Huang High School  81.29  81.51  81.42  80.31
# 8     Johnson High School  81.26  80.77  80.62  81.23
# 9        Pena High School  83.81  83.61  84.34  84.59
# 10  Rodriguez High School  80.99  80.63  80.86  80.38
# 11    Shelton High School  84.12  83.44  84.37  82.78
# 12     Thomas High School  83.73  84.25  83.59  83.83
# 13     Wilson High School  83.94  84.02  83.76  84.32
# 14     Wright High School  83.83  83.81  84.16  84.07

# %%
#Scores by School Spending
due

# %%
#Scores by School Size
due

# %%
#Scores by School Type
due

# %%
#You must include a written description of three observable trends based on the data. 
due
